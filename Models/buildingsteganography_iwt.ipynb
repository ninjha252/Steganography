# %%
STAR_QUOTES = [
    # --- STAR WARS (70) ---
    "[SW] May the Force be with you.",
    "[SW] I find your lack of faith disturbing.",
    "[SW] Do or do not. There is no try.",
    "[SW] I've got a bad feeling about this.",
    "[SW] Never tell me the odds.",
    "[SW] Fear leads to anger, anger leads to hate.",
    "[SW] In my experience, there's no such thing as luck.",
    "[SW] Your eyes can deceive you; don’t trust them.",
    "[SW] I am your father.",
    "[SW] The Force will be with you. Always.",
    "[SW] You were the chosen one!",
    "[SW] Help me, Obi-Wan Kenobi. You're my only hope.",
    "[SW] Aren’t you a little short for a stormtrooper?",
    "[SW] When 900 years old you reach, look as good you will not.",
    "[SW] The Force is strong with this one.",
    "[SW] Now, young Skywalker, you will die.",
    "[SW] These aren’t the droids you’re looking for.",
    "[SW] Let the Wookiee win.",
    "[SW] Stay on target!",
    "[SW] I sense a trap.",
    "[SW] So this is how liberty dies, with thunderous applause.",
    "[SW] There's always a bigger fish.",
    "[SW] I'm just a simple man making my way.",
    "[SW] Experience outranks everything.",
    "[SW] I'm one with the Force. The Force is with me.",
    "[SW] Someday I will be the most powerful Jedi ever.",
    "[SW] Only a Sith deals in absolutes.",
    "[SW] Hello there.",
    "[SW] This is the way.",
    "[SW] He’s no good to me dead.",
    "[SW] This party’s over.",
    "[SW] Women always figure out the truth.",
    "[SW] Laugh it up, fuzzball!",
    "[SW] Chewie, we’re home.",
    "[SW] Rebellions are built on hope.",
    "[SW] I rebel.",
    "[SW] I’m altering the deal. Pray I don’t alter it further.",
    "[SW] Somebody has to save our skins.",
    "[SW] No one’s ever really gone.",
    "[SW] Confronting fear is a Jedi’s destiny.",
    "[SW] The greatest teacher, failure is.",
    "[SW] The ability to speak does not make you intelligent.",
    "[SW] I thought they smelled bad on the outside!",
    "[SW] No. That’s not true. That’s impossible!",
    "[SW] A Jedi uses the Force for knowledge and defense.",
    "[SW] I placed vital info in this R2 unit.",
    "[SW] I am a Jedi, like my father before me.",
    "[SW] I see through the lies of the Jedi.",
    "[SW] Let the past die. Kill it if you have to.",
    "[SW] I know what I have to do.",
    "[SW] The Force is not about lifting rocks.",
    "[SW] I love you. I know.",
    "[SW] I’ve got a bad feeling about this.",
    "[SW] That’s not how the Force works!",
    "[SW] Great shot, kid! That was one in a million!",
    "[SW] Judge me by my size, do you?",
    "[SW] There is another Skywalker.",
    "[SW] Fear leads to anger, anger leads to hate.",
    "[SW] I can bring you in warm or cold.",
    "[SW] I have spoken.",
    "[SW] I am all the Sith!",
    "[SW] And I... am all the Jedi!",
    "[SW] I hate sand. It’s coarse and rough.",
    "[SW] You underestimate my power!",
    "[SW] I have the high ground!",
    "[SW] So be it... Jedi.",
    "[SW] Bounty hunting is a complicated profession.",
    "[SW] I’m just a simple man, trying to make my way.",
    "[SW] Always two there are, no more, no less.",
    "[SW] He’s more machine now than man.",
    "[SW] Never tell me the odds!",
 
    "[AV] I can do this all day.",
    "[AV] We have a Hulk.",
    "[AV] That’s my secret, Cap: I’m always angry.",
    "[AV] I am Iron Man.",
    "[AV] Avengers, assemble!",
    "[AV] Genius, billionaire, playboy, philanthropist.",
    "[AV] I understood that reference.",
    "[AV] Dormammu, I’ve come to bargain.",
    "[AV] Wakanda forever!",
    "[AV] I’m Mary Poppins, y’all!",
    "[AV] I’m with you till the end of the line.",
    "[AV] I’m just a kid from Brooklyn.",
    "[AV] We’re in the endgame now.",
    "[AV] Language!",
    "[AV] If we can’t protect the Earth, we’ll avenge it.",
    "[AV] Puny god.",
    "[AV] Part of the journey is the end.",
    "[AV] I am burdened with glorious purpose.",
    "[AV] I could do this all day. Yeah, I know.",
    "[AV] I’ll do you one better: why is Gamora?",
    "[AV] Get this man a shield.",
    "[AV] He’s a friend from work!",
    "[AV] I choose to run toward my problems.",
    "[AV] It’s not about how much we lost.",
    "[AV] I love you 3000.",
    "[AV] We’re the guardians of the galaxy.",
    "[AV] Nothing goes over my head.",
    "[AV] Fine. I’ll do it myself.",
    "[AV] No resurrections this time.",
    "[AV] On your left.",
    "[AV] I’m made of rocks, as you can see.",
    "[AV] Bring me Thanos!",
    "[AV] This isn’t a team, it’s a time bomb.",
    "[AV] You should have aimed for the head.",
    "[AV] Dread it, run from it, destiny arrives all the same.",
    "[AV] I am inevitable.",
    "[AV] We work with what we got.",
    "[AV] If you’re nothing without the suit...",
    "[AV] Is that the best you can do?",
    "[AV] I’m gonna need that guy’s arm.",
    "[AV] Another happy landing. (Wrong franchise, sorry.)",
    "[AV] We are in the Endgame now.",
    "[AV] She’s not alone.",
    "[AV] That’s America’s ass.",
    "[AV] It’s an oversimplification of events, but yes.",
    "[AV] I’m a huge fan of the way you lose control.",
    "[AV] I prefer the weapon you only have to fire once.",
    "[AV] We create our own demons.",
    "[AV] Nothing lasts forever.",
    "[AV] Victory should be effortless.",
    "[AV] You’re out of time.",
    "[AV] I’m a god, you dull creature!",
    "[AV] Underoos!",
    "[AV] I can’t control their fear, only mine.",
    "[AV] There was an idea...",
    "[AV] Whatever it takes.",
    "[AV] A friend of mine once said...",
    "[AV] I see a suit of armor around the world.",
    "[AV] It’s not a great plan.",
    "[AV] I’m loyal to nothing except the dream.",
    "[AV] I’m not looking for forgiveness.",
    "[AV] You’re not the guy to make the sacrifice play.",
    "[AV] You get hurt, hurt ’em back.",
    "[AV] Gotta move on. We gotta move on.",
    "[AV] You could not live with your own failure.",
    "[AV] In my culture, death is not the end.",
    "[AV] Is this your king?",
    "[AV] This is my burden to bear.",
    "[AV] If you die, I feel like that’s on me.",
    "[AV] I don’t want to go.",
    "[AV] Part of the journey is the end.",
    

    "[SR] Hope is a good thing, maybe the best of things.",
    "[SR] Get busy living or get busy dying.",
    "[SR] I guess it comes down to a simple choice.",
    "[SR] Remember, Red, hope is a good thing.",
    "[SR] Salvation lies within.",
    "[SR] That’s the beauty of music.",
    "[SR] A man’s got to have something to keep him sane.",
    "[SR] I had to come to prison to be a crook.",
    "[SR] Hope can drive a man insane.",
    "[SR] Geology is the study of pressure and time.",
    "[SR] I guess I just miss my friend.",
    "[SR] I find I'm so excited, I can barely sit still.",
    "[SR] I'd like to think the last thing that went through his head.",
    "[SR] The world went and got itself in a big hurry.",
    "[SR] The Pacific Ocean has no memory.",
    "[SR] Andy crawled to freedom.",
    "[SR] Same old stuff, different day.",
    "[SR] You eat when we say you eat.",
    "[SR] That’s the one thing they can’t take away.",
    "[SR] The roof of the license-plate factory.",
    "[SR] We sat and drank with the sun on our shoulders.",
    "[SR] Terrible thing, to live in fear.",
    "[SR] He strolled like a man in a park.",
    "[SR] There’s something inside that they can’t get to.",
    "[SR] Some birds aren’t meant to be caged.",
    "[SR] They’re just too bright.",
    "[SR] Fear can hold you prisoner.",
    "[SR] Hope can set you free.",
    "[SR] Bad luck, I guess. It floats around.",
    "[SR] The library, pure as a soap opera.",
    "[SR] I don’t waste time on losers, Tommy.",
    "[SR] How could you be so obtuse?",
    "[SR] I like to think the last thing that went through his head was to wonder.",
    "[SR] Lord, it’s a miracle!",
    "[SR] They send you here for life, and that’s exactly what they take.",
    "[SR] We’re getting to be regular old friends.",
    "[SR] Andy Dufresne, who crawled through a river of filth.",
    "[SR] He didn't do it, and I believe him.",
    "[SR] In prison, a man will do almost anything to keep his mind occupied.",
    "[SR] That’s it, step aside, Mert.",
    "[SR] I had Mr. Mozart to keep me company.",
    "[SR] I have no idea to this day what those two Italian ladies were singing about.",
    "[SR] They can’t touch the music.",
    "[SR] We sat and drank with the sun on our shoulders.",
    "[SR] I'd hate to deprive you of this.",
    "[SR] I killed her, Red.",
    "[SR] I didn’t pull the trigger, but I drove her away.",
    "[SR] Sometimes it makes me sad, though.",
    "[SR] Brooks was here, so was Red.",
    "[SR] Maybe it’s because I’m Irish.",
    "[SR] You strike me as a particularly icy and remorseless man.",
    "[SR] I'd grow eyes in the back of my head if I were you.",
    "[SR] I’m a convicted murderer who provides sound financial planning.",
    "[SR] That’s the best part of me left in me.",
    "[SR] I don’t suppose it would help any if I explained again.",
    "[SR] You better start making sense, kid.",
    "[SR] This is a tall drink of water named Andy Dufresne.",
    "[SR] Forty years I been asking permission to pee.",
    "[SR] It broke my heart to see him like that.",
    "[SR] There's a harsh truth to face.",
    "[SR] Perhaps it's time you tried a new profession.",
    "[SR] How about we get her some rocks?",
    "[SR] That’s where I want to live the rest of my life.",
    "[SR] The bars slam home, that’s when you know it’s for real.",
    "[SR] I must admit I didn’t think much of Andy.",
    "[SR] He fought the good fight, and the sisters never laid a finger on him again.",
    "[SR] Remember that hope is a good thing.",
    "[SR] Some places are like that, though: big old bones.",
    "[SR] Let me tell you something, my friend: hope is dangerous.",
    "[SR] Hope is a dangerous thing. Drive a man insane.",
    "[SR] I hope I can make it across the border.",
    
    # --- HARRY POTTER (70) ---
    "[HP] It does not do to dwell on dreams.",
    "[HP] Happiness can be found even in the darkest of times.",
    "[HP] Fear of a name increases fear of the thing itself.",
    "[HP] We’ve all got both light and dark inside us.",
    "[HP] I solemnly swear that I am up to no good.",
    "[HP] Working hard is important, but there is something that matters even more.",
    "[HP] It matters not what someone is born, but what they grow to be.",
    "[HP] Words are, in my not-so-humble opinion, our most inexhaustible source of magic.",
    "[HP] It takes a great deal of bravery to stand up to our enemies.",
    "[HP] But it takes even more to stand up to our friends.",
    "[HP] Dark and difficult times lie ahead.",
    "[HP] Until the very end.",
    "[HP] After all this time? Always.",
    "[HP] We could all have been killed, or worse, expelled.",
    "[HP] Of course it’s happening inside your head.",
    "[HP] Just because you have the emotional range of a teaspoon.",
    "[HP] Every human life is worth the same.",
    "[HP] You’re a wizard, Harry.",
    "[HP] I am what I am, and I’m not ashamed.",
    "[HP] If you want to know what a man’s like, take a good look at how he treats his inferiors.",
    "[HP] I can teach you how to bottle fame.",
    "[HP] The ones that love us never really leave us.",
    "[HP] Don’t let the muggles get you down.",
    "[HP] We must all face the choice between what is right and what is easy.",
    "[HP] Time is making fools of us again.",
    "[HP] I want to commit the murder I was imprisoned for.",
    "[HP] Mischief managed!",
    "[HP] Curiosity is not a sin.",
    "[HP] I’m holy. I’m holey, Fred, geddit?",
    "[HP] Yer a wizard, Harry.",
    "[HP] Dobby is free.",
    "[HP] Let us step into the night and pursue that flighty temptress, adventure.",
    "[HP] If you’re holding out for universal popularity, you’ll be in this cabin a long time.",
    "[HP] Always the tone of surprise.",
    "[HP] He will only be gone from the school when none here are loyal to him.",
    "[HP] Numbing the pain for a while will make it worse when you finally feel it.",
    "[HP] Books! And cleverness!",
    "[HP] I solemnly swear I am up to no good.",
    "[HP] Don’t pity the dead, Harry. Pity the living.",
    "[HP] It’s our choices that show what we truly are.",
    "[HP] I’ll join you when hell freezes over.",
    "[HP] Every time I try to help, people get hurt.",
    "[HP] Once again, you’ve put your keen mind to the task.",
    "[HP] Fawkes is a phoenix, Harry.",
    "[HP] Greatness inspires envy.",
    "[HP] Dumbledore’s got style.",
    "[HP] Dumbledore said people find it far easier to forgive others.",
    "[HP] Let us not deprive Molly any longer of the chance to deplore.",
    "[HP] Hearing voices no one else can hear isn’t a good sign.",
    "[HP] The Chamber of Secrets has been opened.",
    "[HP] I’ll be in my bedroom, making no noise.",
    "[HP] Training for the ballet, Potter?",
    "[HP] You’ll soon find out that some wizarding families are better than others.",
    "[HP] Ah, music. A magic beyond all we do here!",
    "[HP] Have a biscuit, Potter.",
    "[HP] Let us hope that Mr. Potter will always be around.",
    "[HP] Dobby never meant to kill. Only maim or seriously injure.",
    "[HP] It’s not a question of can or can’t.",
    "[HP] This is beyond anything I imagined.",
    "[HP] If you have to ask, you’ll never know.",
    "[HP] Wands are only as powerful as the wizards who use them.",
    "[HP] I’m going to bed before either of you come up with another idea.",
    "[HP] It’s LeviOsa, not LevioSA!",
    "[HP] We’ve all got both light and dark inside us.",
    "[HP] Fear of a name only increases fear of the thing itself.",
    "[HP] Avada Kedavra’s got a curse on it.",
    "[HP] Yer a wizard, Harry. (Yes, again!)",
    
    # --- THE LORD OF THE RINGS (70) ---
    "[LOTR] Even the smallest person can change the course of the future.",
    "[LOTR] All we have to decide is what to do with the time given us.",
    "[LOTR] Not all those who wander are lost.",
    "[LOTR] You shall not pass!",
    "[LOTR] One does not simply walk into Mordor.",
    "[LOTR] There is always hope.",
    "[LOTR] My precious.",
    "[LOTR] Deeds will not be less valiant because they are unpraised.",
    "[LOTR] A wizard is never late.",
    "[LOTR] I would rather share one lifetime with you.",
    "[LOTR] I can't carry it for you, but I can carry you!",
    "[LOTR] Even darkness must pass.",
    "[LOTR] There’s some good in this world, Mr. Frodo.",
    "[LOTR] The board is set, the pieces are moving.",
    "[LOTR] It’s the deep breath before the plunge.",
    "[LOTR] A day may come when the courage of men fails.",
    "[LOTR] That day is not this day.",
    "[LOTR] Fool of a Took!",
    "[LOTR] I am no man!",
    "[LOTR] Certainty of death, small chance of success.",
    "[LOTR] The age of men is over. The time of the Orc has come.",
    "[LOTR] Let him go, you filth!",
    "[LOTR] There will come a time, but it is not now.",
    "[LOTR] We swears, to serve the master of the Precious.",
    "[LOTR] Don’t adventures ever have an end?",
    "[LOTR] Even the very wise cannot see all ends.",
    "[LOTR] It's a dangerous business, Frodo, going out your door.",
    "[LOTR] If more of us valued food and cheer above hoarded gold...",
    "[LOTR] A red sun rises. Blood has been spilled.",
    "[LOTR] Kings made tombs more splendid than houses of the living.",
    "[LOTR] The fires of Isengard will spread.",
    "[LOTR] There is no curse in Elvish for this treachery.",
    "[LOTR] I will take the Ring, though I do not know the way.",
    "[LOTR] That is no trinket you carry.",
    "[LOTR] Gondor calls for aid!",
    "[LOTR] And Rohan will answer.",
    "[LOTR] You bow to no one.",
    "[LOTR] The world is changed. I feel it in the water.",
    "[LOTR] I’m going on an adventure!",
    "[LOTR] I’d rather be dead than see my kin bow to Sauron.",
    "[LOTR] The Eye of the enemy is moving.",
    "[LOTR] One ring to rule them all.",
    "[LOTR] This task was appointed to you.",
    "[LOTR] Let him not vow to walk in the dark.",
    "[LOTR] There is no life in the void.",
    "[LOTR] A steward's only duty is to his people.",
    "[LOTR] Release the river!",
    "[LOTR] War will make corpses of us all.",
    "[LOTR] Do not trouble yourself with my problems.",
    "[LOTR] The Grey Pilgrim, that’s what they used to call me.",
    "[LOTR] Men of Gondor! Of Rohan! My brothers!",
    "[LOTR] Let this be the hour we draw swords together.",
    "[LOTR] Ride now! Ride for ruin!",
    "[LOTR] I can't do this, Sam.",
    "[LOTR] There's some good in this world.",
    "[LOTR] You have my sword.",
    "[LOTR] And my bow.",
    "[LOTR] And my axe.",
    "[LOTR] The shadow does not hold sway yet.",
    "[LOTR] I think I broke something.",
    "[LOTR] It’s not natural, none of it.",
    "[LOTR] I’d cut off your head, Dwarf, if it stood but a little higher.",
    "[LOTR] You need people of intelligence on this mission.",
    "[LOTR] The Ring has awoken. It’s heard its master’s call.",
    "[LOTR] If you want him, come and claim him!",
    "[LOTR] The treacherous are ever distrustful.",
    "[LOTR] You shall be the Fellowship of the Ring.",
    "[LOTR] That’s what I meant: perilous.",
    "[LOTR] A hunted man sometimes wearies of distrust and longs for friendship.",
    "[LOTR] I will not say do not weep.",
    "[LOTR] This is no mere ranger.",
    "[LOTR] Your time will come. You will face the same Evil.",
    "[LOTR] Even the smallest person can change the future."
]

# %%
import os
import random
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

###############################################################################
# 1) INTEGER HAAR 1D (FORWARD & INVERSE)
###############################################################################
def int_haar_1d_forward(signal):
    """
    Integer 1D Haar Transform (lifting-based) on a 1D array of even length.
    Produces approx[] and detail[] as integers.
    """
    n = len(signal)
    half = n // 2
    approx = np.zeros(half, dtype=int)
    detail = np.zeros(half, dtype=int)

    for i in range(half):
        s0 = signal[2*i]
        s1 = signal[2*i+1]
        d = s1 - s0
        a = s0 + (d // 2)
        detail[i] = d
        approx[i] = a

    return approx, detail

def int_haar_1d_inverse(approx, detail):
    """
    Inverse Integer 1D Haar Transform (lifting-based).
    """
    half = len(approx)
    n = half * 2
    out = np.zeros(n, dtype=int)
    for i in range(half):
        a = approx[i]
        d = detail[i]
        s0 = a - (d // 2)
        s1 = d + s0
        out[2*i] = s0
        out[2*i+1] = s1
    return out

###############################################################################
# 2) INTEGER HAAR 2D (FORWARD & INVERSE)
###############################################################################
def int_haar_2d_forward(img_array):
    """
    Single-level 2D Integer Haar Transform on a 2D array (H x W).
    Returns (LL, LH, HL, HH), all int arrays.
    Assumes even width, even height.
    """
    h, w = img_array.shape

    # 1) Transform each row
    row_approx = np.zeros_like(img_array, dtype=int)
    row_detail = np.zeros_like(img_array, dtype=int)
    for r in range(h):
        approx, detail = int_haar_1d_forward(img_array[r, :])
        row_approx[r, 0:(w//2)] = approx
        row_detail[r, 0:(w//2)] = detail

    # 2) Transform columns of row_approx => (LL, HL)
    #    Transform columns of row_detail => (LH, HH)
    LL = np.zeros((h//2, w//2), dtype=int)
    HL = np.zeros((h//2, w//2), dtype=int)
    LH = np.zeros((h//2, w//2), dtype=int)
    HH = np.zeros((h//2, w//2), dtype=int)

    for c in range(w//2):
        col_data = row_approx[:, c]
        a_col, d_col = int_haar_1d_forward(col_data)
        for rr in range(h//2):
            LL[rr, c] = a_col[rr]
            HL[rr, c] = d_col[rr]

    for c in range(w//2):
        col_data = row_detail[:, c]
        a_col, d_col = int_haar_1d_forward(col_data)
        for rr in range(h//2):
            LH[rr, c] = a_col[rr]
            HH[rr, c] = d_col[rr]

    return LL, LH, HL, HH

def int_haar_2d_inverse(LL, LH, HL, HH):
    """
    Inverse Single-level 2D Integer Haar Transform.
    """
    h2, w2 = LL.shape
    h = h2 * 2
    w = w2 * 2

    # Rebuild row_approx from LL, HL
    row_approx = np.zeros((h, w2), dtype=int)
    row_detail = np.zeros((h, w2), dtype=int)

    for c in range(w2):
        approx_col = LL[:, c]
        detail_col = HL[:, c]
        col_data = int_haar_1d_inverse(approx_col, detail_col)
        for rr in range(h):
            row_approx[rr, c] = col_data[rr]

    for c in range(w2):
        approx_col = LH[:, c]
        detail_col = HH[:, c]
        col_data = int_haar_1d_inverse(approx_col, detail_col)
        for rr in range(h):
            row_detail[rr, c] = col_data[rr]

    # Now inverse row-based transform
    out_array = np.zeros((h, w), dtype=int)
    for rr in range(h):
        a_row = row_approx[rr, :]
        d_row = row_detail[rr, :]
        row_data = int_haar_1d_inverse(a_row, d_row)
        out_array[rr, :] = row_data

    return out_array

###############################################################################
# 3) EMBED & EXTRACT (LH SUB-BAND)
###############################################################################
def iwt_embed(cover_path, secret_message, stego_path):
    """
    1) Load grayscale image, auto-resize to even dims (round up).
    2) int_haar_2d_forward => (LL, LH, HL, HH)
    3) Embed bits in LH's LSB
    4) int_haar_2d_inverse => stego
    5) Save as PNG
    """
    cover_img = Image.open(cover_path).convert("L")
    w, h = cover_img.size

    # Round up to even dims if needed
    new_w = w if (w % 2 == 0) else (w + 1)
    new_h = h if (h % 2 == 0) else (h + 1)
    if (new_w != w) or (new_h != h):
        cover_img = cover_img.resize((new_w, new_h), Image.LANCZOS)
        print(f"Resized image from {w}x{h} to {new_w}x{new_h} for even dims.")
        w, h = new_w, new_h

    cover_array = np.array(cover_img, dtype=int)

    # Forward IWT
    LL, LH, HL, HH = int_haar_2d_forward(cover_array)

    # Prepare bits
    secret_bytes = secret_message.encode('utf-8')
    secret_bits = ''.join(f'{byte:08b}' for byte in secret_bytes)
    end_marker = '1111111111111110'
    full_bits = secret_bits + end_marker

    lh_flat = LH.flatten()
    if len(full_bits) > len(lh_flat):
        raise ValueError("Not enough capacity in LH sub-band.")

    # Embed
    for i, bit in enumerate(full_bits):
        val = lh_flat[i]
        if bit == '1':
            val |= 1
        else:
            val &= ~1
        lh_flat[i] = val

    LH_modified = lh_flat.reshape(LH.shape)

    # Inverse IWT
    stego_array = int_haar_2d_inverse(LL, LH_modified, HL, HH)
    stego_array = np.clip(stego_array, 0, 255).astype('uint8')

    # Save
    stego_img = Image.fromarray(stego_array, mode='L')
    stego_img.save(stego_path, format="PNG")
    print(f"IWT embedding done. Saved stego image to: {stego_path}")

def iwt_extract(stego_path):
    """
    1) Load stego (grayscale), auto-resize to even dims if needed? (Better not, or you'll mismatch)
    2) int_haar_2d_forward => (LL, LH, HL, HH)
    3) Read bits from LH until marker '1111111111111110'
    """
    stego_img = Image.open(stego_path).convert("L")
    w, h = stego_img.size

    # Because we resized in embed, the stego is definitely even dims
    # but if you want to be safe, do the same approach (round up).
    # In theory, the stego is EXACT dims from embed time, so we can skip resizing.
    if (w % 2 != 0) or (h % 2 != 0):
        print(f"Warning: stego has odd dims {w}x{h}, forcibly resizing. Might cause mismatch.")
        new_w = w if (w % 2 == 0) else (w + 1)
        new_h = h if (h % 2 == 0) else (h + 1)
        stego_img = stego_img.resize((new_w, new_h), Image.LANCZOS)
        w, h = new_w, new_h

    stego_array = np.array(stego_img, dtype=int)

    LL, LH, HL, HH = int_haar_2d_forward(stego_array)

    lh_flat = LH.flatten()
    marker = '1111111111111110'
    bits_collected = []

    for val in lh_flat:
        bit = val & 1
        bits_collected.append(str(bit))

        if len(bits_collected) >= len(marker):
            recent = ''.join(bits_collected[-len(marker):])
            if recent == marker:
                all_bits = ''.join(bits_collected[:-len(marker)])
                secret_bytes = []
                for i in range(0, len(all_bits), 8):
                    chunk = all_bits[i:i+8]
                    if len(chunk) < 8:
                        break
                    secret_bytes.append(int(chunk, 2))
                return bytes(secret_bytes).decode('utf-8', errors='ignore')
    return ""

# %%
import os
import random
import pandas as pd
from pathlib import Path


INITIAL_DIR    = Path("initial")
STEGO_IWT_DIR  = Path("stego_iwt")
CSV_IWT        = Path("csv") / "iwt_succ_stego.csv"

# 1) Prepare output directories
STEGO_IWT_DIR.mkdir(parents=True, exist_ok=True)
CSV_IWT.parent.mkdir(parents=True, exist_ok=True)

# 2) Gather the remaining images (those not LSB‐processed)
remaining = [
    p for p in INITIAL_DIR.iterdir()
    if p.is_file()
       and p.suffix.lower() in {".jpg", ".jpeg", ".png", ".bmp"}
       and not p.stem.startswith("lsb_")
]

# 3) Sample up to 1000 for IWT embedding
to_encode = random.sample(remaining, min(1000, len(remaining)))

records = []

for idx, orig in enumerate(to_encode, start=1):
    ext     = orig.suffix.lower()
    renamed = INITIAL_DIR / f"iwt_{idx}{ext}"
    orig.rename(renamed)

    # pick a random quote and embed
    secret     = random.choice(STAR_QUOTES)
    stego_path = STEGO_IWT_DIR / f"iwt_{idx}{ext}"
    iwt_embed(str(renamed), secret, str(stego_path))

    # verify extraction
    try:
        extracted = iwt_extract(str(stego_path))
        if extracted == secret:
            records.append({
                "original_path":   str(renamed),
                "stego_path":      str(stego_path),
                "method":          "iwt",
                "secret_message":  secret
            })
        else:
            # delete failed stego
            stego_path.unlink()
    except Exception:
        if stego_path.exists():
            stego_path.unlink()

# 4) Write out successes
df = pd.DataFrame(records, columns=[
    "original_path", "stego_path", "method", "secret_message"
])
df.to_csv(CSV_IWT, index=False)

print(f"IWT pass done: {len(records)} images embedded+verified.")
print(f"Success log written to {CSV_IWT}")
# Out:
# IWT embedding done. Saved stego image to: stego_iwt/iwt_1.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_2.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_3.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_4.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_5.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_6.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_7.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_8.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_9.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_10.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_11.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_12.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_13.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_14.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_15.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_16.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_17.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_18.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_19.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_20.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_21.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_22.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_23.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_24.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_25.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_26.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_27.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_28.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_29.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_30.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_31.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_32.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_33.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_34.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_35.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_36.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_37.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_38.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_39.jpg
# Resized image from 1024x711 to 1024x712 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_40.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_41.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_42.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_43.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_44.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_45.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_46.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_47.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_48.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_49.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_50.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_51.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_52.jpg
# Resized image from 1024x693 to 1024x694 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_53.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_54.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_55.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_56.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_57.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_58.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_59.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_60.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_61.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_62.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_63.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_64.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_65.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_66.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_67.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_68.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_69.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_70.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_71.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_72.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_73.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_74.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_75.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_76.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_77.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_78.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_79.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_80.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_81.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_82.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_83.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_84.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_85.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_86.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_87.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_88.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_89.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_90.jpg
# Resized image from 1023x731 to 1024x732 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_91.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_92.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_93.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_94.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_95.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_96.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_97.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_98.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_99.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_100.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_101.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_102.jpg
# Resized image from 1024x771 to 1024x772 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_103.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_104.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_105.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_106.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_107.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_108.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_109.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_110.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_111.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_112.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_113.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_114.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_115.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_116.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_117.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_118.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_119.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_120.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_121.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_122.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_123.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_124.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_125.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_126.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_127.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_128.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_129.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_130.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_131.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_132.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_133.jpg
# Resized image from 1024x643 to 1024x644 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_134.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_135.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_136.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_137.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_138.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_139.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_140.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_141.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_142.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_143.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_144.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_145.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_146.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_147.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_148.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_149.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_150.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_151.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_152.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_153.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_154.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_155.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_156.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_157.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_158.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_159.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_160.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_161.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_162.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_163.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_164.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_165.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_166.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_167.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_168.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_169.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_170.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_171.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_172.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_173.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_174.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_175.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_176.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_177.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_178.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_179.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_180.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_181.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_182.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_183.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_184.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_185.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_186.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_187.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_188.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_189.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_190.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_191.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_192.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_193.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_194.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_195.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_196.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_197.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_198.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_199.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_200.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_201.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_202.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_203.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_204.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_205.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_206.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_207.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_208.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_209.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_210.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_211.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_212.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_213.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_214.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_215.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_216.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_217.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_218.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_219.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_220.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_221.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_222.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_223.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_224.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_225.jpg
# Resized image from 1023x731 to 1024x732 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_226.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_227.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_228.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_229.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_230.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_231.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_232.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_233.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_234.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_235.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_236.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_237.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_238.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_239.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_240.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_241.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_242.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_243.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_244.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_245.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_246.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_247.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_248.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_249.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_250.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_251.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_252.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_253.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_254.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_255.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_256.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_257.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_258.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_259.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_260.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_261.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_262.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_263.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_264.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_265.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_266.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_267.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_268.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_269.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_270.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_271.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_272.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_273.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_274.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_275.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_276.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_277.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_278.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_279.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_280.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_281.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_282.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_283.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_284.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_285.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_286.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_287.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_288.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_289.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_290.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_291.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_292.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_293.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_294.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_295.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_296.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_297.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_298.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_299.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_300.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_301.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_302.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_303.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_304.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_305.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_306.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_307.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_308.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_309.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_310.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_311.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_312.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_313.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_314.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_315.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_316.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_317.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_318.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_319.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_320.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_321.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_322.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_323.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_324.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_325.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_326.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_327.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_328.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_329.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_330.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_331.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_332.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_333.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_334.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_335.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_336.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_337.jpg
# Resized image from 683x1024 to 684x1024 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_338.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_339.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_340.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_341.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_342.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_343.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_344.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_345.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_346.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_347.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_348.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_349.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_350.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_351.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_352.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_353.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_354.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_355.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_356.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_357.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_358.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_359.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_360.jpg
# Resized image from 1023x681 to 1024x682 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_361.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_362.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_363.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_364.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_365.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_366.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_367.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_368.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_369.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_370.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_371.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_372.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_373.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_374.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_375.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_376.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_377.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_378.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_379.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_380.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_381.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_382.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_383.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_384.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_385.jpg
# Resized image from 1024x509 to 1024x510 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_386.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_387.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_388.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_389.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_390.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_391.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_392.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_393.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_394.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_395.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_396.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_397.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_398.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_399.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_400.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_401.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_402.jpg
# Resized image from 1023x681 to 1024x682 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_403.jpg
# Resized image from 1023x731 to 1024x732 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_404.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_405.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_406.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_407.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_408.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_409.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_410.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_411.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_412.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_413.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_414.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_415.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_416.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_417.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_418.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_419.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_420.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_421.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_422.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_423.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_424.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_425.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_426.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_427.jpg
# Resized image from 683x1024 to 684x1024 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_428.jpg
# Resized image from 683x1024 to 684x1024 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_429.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_430.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_431.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_432.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_433.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_434.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_435.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_436.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_437.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_438.jpg
# Resized image from 1023x681 to 1024x682 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_439.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_440.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_441.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_442.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_443.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_444.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_445.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_446.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_447.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_448.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_449.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_450.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_451.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_452.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_453.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_454.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_455.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_456.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_457.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_458.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_459.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_460.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_461.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_462.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_463.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_464.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_465.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_466.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_467.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_468.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_469.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_470.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_471.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_472.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_473.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_474.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_475.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_476.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_477.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_478.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_479.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_480.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_481.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_482.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_483.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_484.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_485.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_486.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_487.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_488.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_489.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_490.jpg
# Resized image from 683x1024 to 684x1024 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_491.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_492.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_493.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_494.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_495.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_496.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_497.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_498.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_499.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_500.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_501.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_502.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_503.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_504.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_505.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_506.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_507.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_508.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_509.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_510.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_511.jpg
# Resized image from 1023x681 to 1024x682 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_512.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_513.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_514.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_515.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_516.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_517.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_518.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_519.jpg
# Resized image from 1024x757 to 1024x758 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_520.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_521.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_522.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_523.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_524.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_525.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_526.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_527.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_528.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_529.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_530.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_531.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_532.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_533.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_534.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_535.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_536.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_537.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_538.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_539.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_540.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_541.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_542.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_543.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_544.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_545.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_546.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_547.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_548.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_549.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_550.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_551.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_552.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_553.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_554.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_555.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_556.jpg
# Resized image from 1023x681 to 1024x682 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_557.jpg
# Resized image from 1024x577 to 1024x578 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_558.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_559.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_560.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_561.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_562.jpg
# Resized image from 1024x643 to 1024x644 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_563.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_564.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_565.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_566.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_567.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_568.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_569.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_570.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_571.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_572.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_573.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_574.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_575.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_576.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_577.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_578.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_579.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_580.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_581.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_582.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_583.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_584.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_585.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_586.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_587.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_588.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_589.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_590.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_591.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_592.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_593.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_594.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_595.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_596.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_597.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_598.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_599.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_600.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_601.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_602.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_603.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_604.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_605.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_606.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_607.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_608.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_609.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_610.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_611.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_612.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_613.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_614.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_615.jpg
# Resized image from 1023x681 to 1024x682 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_616.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_617.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_618.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_619.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_620.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_621.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_622.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_623.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_624.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_625.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_626.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_627.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_628.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_629.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_630.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_631.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_632.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_633.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_634.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_635.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_636.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_637.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_638.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_639.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_640.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_641.jpg
# Resized image from 683x1024 to 684x1024 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_642.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_643.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_644.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_645.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_646.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_647.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_648.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_649.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_650.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_651.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_652.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_653.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_654.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_655.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_656.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_657.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_658.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_659.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_660.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_661.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_662.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_663.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_664.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_665.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_666.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_667.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_668.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_669.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_670.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_671.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_672.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_673.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_674.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_675.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_676.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_677.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_678.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_679.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_680.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_681.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_682.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_683.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_684.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_685.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_686.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_687.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_688.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_689.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_690.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_691.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_692.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_693.jpg
# ...
# IWT embedding done. Saved stego image to: stego_iwt/iwt_777.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_778.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_779.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_780.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_781.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_782.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_783.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_784.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_785.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_786.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_787.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_788.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_789.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_790.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_791.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_792.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_793.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_794.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_795.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_796.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_797.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_798.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_799.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_800.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_801.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_802.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_803.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_804.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_805.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_806.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_807.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_808.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_809.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_810.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_811.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_812.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_813.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_814.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_815.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_816.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_817.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_818.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_819.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_820.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_821.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_822.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_823.jpg
# Resized image from 683x1024 to 684x1024 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_824.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_825.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_826.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_827.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_828.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_829.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_830.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_831.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_832.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_833.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_834.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_835.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_836.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_837.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_838.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_839.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_840.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_841.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_842.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_843.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_844.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_845.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_846.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_847.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_848.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_849.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_850.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_851.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_852.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_853.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_854.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_855.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_856.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_857.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_858.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_859.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_860.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_861.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_862.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_863.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_864.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_865.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_866.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_867.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_868.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_869.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_870.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_871.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_872.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_873.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_874.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_875.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_876.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_877.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_878.jpg
# Resized image from 1023x681 to 1024x682 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_879.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_880.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_881.jpg
# Resized image from 1023x681 to 1024x682 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_882.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_883.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_884.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_885.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_886.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_887.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_888.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_889.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_890.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_891.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_892.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_893.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_894.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_895.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_896.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_897.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_898.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_899.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_900.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_901.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_902.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_903.jpg
# Resized image from 1024x803 to 1024x804 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_904.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_905.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_906.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_907.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_908.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_909.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_910.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_911.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_912.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_913.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_914.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_915.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_916.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_917.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_918.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_919.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_920.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_921.jpg
# Resized image from 1024x765 to 1024x766 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_922.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_923.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_924.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_925.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_926.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_927.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_928.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_929.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_930.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_931.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_932.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_933.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_934.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_935.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_936.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_937.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_938.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_939.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_940.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_941.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_942.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_943.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_944.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_945.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_946.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_947.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_948.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_949.jpg
# Resized image from 731x1023 to 732x1024 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_950.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_951.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_952.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_953.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_954.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_955.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_956.jpg
# Resized image from 1023x681 to 1024x682 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_957.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_958.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_959.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_960.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_961.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_962.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_963.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_964.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_965.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_966.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_967.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_968.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_969.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_970.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_971.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_972.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_973.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_974.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_975.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_976.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_977.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_978.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_979.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_980.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_981.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_982.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_983.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_984.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_985.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_986.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_987.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_988.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_989.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_990.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_991.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_992.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_993.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_994.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_995.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_996.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_997.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_998.jpg
# IWT embedding done. Saved stego image to: stego_iwt/iwt_999.jpg
# Resized image from 1024x683 to 1024x684 for even dims.
# IWT embedding done. Saved stego image to: stego_iwt/iwt_1000.jpg
# IWT pass done: 897 images embedded+verified.
# Success log written to csv/iwt_succ_stego.csv

# %%
import os
import shutil
import pandas as pd
from pathlib import Path

# ──────────────────────────────────────────────────────────────────────────────
# CONFIGURATION
# ──────────────────────────────────────────────────────────────────────────────
LSB_CSV      = Path("csv") / "lsb_succ_stego.csv"
IWT_CSV      = Path("csv") / "iwt_succ_stego.csv"
STEGO_LSB_DIR= Path("stego")
STEGO_IWT_DIR= Path("stego_iwt")
FINAL_DIR    = Path("stego_final")
FINAL_CSV    = Path("csv") / "stego_final.csv"

# ──────────────────────────────────────────────────────────────────────────────
# 1) Create final directory
# ──────────────────────────────────────────────────────────────────────────────
FINAL_DIR.mkdir(parents=True, exist_ok=True)

# ──────────────────────────────────────────────────────────────────────────────
# 2) Load and combine both logs
# ──────────────────────────────────────────────────────────────────────────────
df_lsb = pd.read_csv(LSB_CSV)
df_iwt = pd.read_csv(IWT_CSV)
df     = pd.concat([df_lsb, df_iwt], ignore_index=True)

# ──────────────────────────────────────────────────────────────────────────────
# 3) Copy each stego image into stego_final/ and update its path
# ──────────────────────────────────────────────────────────────────────────────
new_paths = []
for stego_path in df["stego_path"]:
    src = Path(stego_path)
    if not src.exists():
        print(f"Warning: {src} not found, skipping.")
        new_paths.append("")
        continue

    dst = FINAL_DIR / src.name
    shutil.copy(src, dst)
    new_paths.append(str(dst))

df["stego_path"] = new_paths

# ──────────────────────────────────────────────────────────────────────────────
# 4) Write out final combined CSV
# ──────────────────────────────────────────────────────────────────────────────
df.to_csv(FINAL_CSV, index=False)

print(f"All stego images merged into '{FINAL_DIR}/'")
print(f"Combined log written to '{FINAL_CSV}'")
# Out:
# All stego images merged into 'stego_final/'
# Combined log written to 'csv/stego_final.csv'
